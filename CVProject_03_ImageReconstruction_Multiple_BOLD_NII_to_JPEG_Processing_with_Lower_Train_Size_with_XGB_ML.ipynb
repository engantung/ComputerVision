# %% [markdown]
# <a href="https://colab.research.google.com/github/engantung/ComputerVision/blob/master/CVProject_03_ImageReconstruction_Multiple_BOLD_NII_to_JPEG_Processing_with_Lower_Train_Size_with_XGB_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python -V
# Out:
# Python 3.6.9

# %%
###################### Only if you use Google Colab ############################
###################### B E G I N Google Colab Code #############################
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %cd /content/drive/My\ Drive/SUMMER\ Project\ 2020/RB_Course/Final_Project/Image_Reconstruction/
# Out:
# /content/drive/My Drive/SUMMER Project 2020/RB_Course/Final_Project/Image_Reconstruction

# %%
# !ls
# Out:
# bp_images  Readme.txt  result_images  stimulus_images  tsv_images

# %%
import sys
sys.path.append('content/drive/My Drive/SUMMER Project 2020//RB_Course/Final_Project/Image_Reconstruction/')

# %%
"""
Created on August 2020

@author: 
    Edmond Hendrik Jacob Ngantung   002258356
    Tian Pei                        002255408
    Hang Cheng                      002263996
"""

import numpy as np
import matplotlib.pyplot as plt
from PIL import Image, ImageOps
import nibabel as nib 
import pandas as pd
from skimage.io import imread

import glob
import cv2
import os
import matplotlib.gridspec as gridspec
import xgboost as xgb

from sklearn.pipeline import make_pipeline
from sklearn.ensemble import RandomForestRegressor, BaggingRegressor, GradientBoostingRegressor, AdaBoostRegressor

from sklearn.model_selection import train_test_split
from sklearn.random_projection import GaussianRandomProjection
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn.kernel_approximation import RBFSampler
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPClassifier

# %%
def train_display(regressor, image_input1, image_input2, image_target, TTS_training_size, TTS_random_state):
    #height, width, length = image_target.shape
    height, width = image_target.shape
    
    flat_image_input1 = np.reshape(image_input1,-1)
    flat_image_input2 = np.reshape(image_input2,-1)
    flat_image_target = np.reshape(image_target,-1)
    #flat_image_input1 = image_input1.reshape(-1)
    #flat_image_input2 = image_input2.reshape(-1)
    #flat_image_target = image_target.reshape(-1)
    
    #xs = np.arange(len(flat_image_input1)) % width
    xs = flat_image_input1
    #ys = np.arange(len(flat_image_input2)) // width 
    ys = flat_image_input2
     
    #print(ys.shape)
    data = np.array([xs, ys]).T
    target = flat_image_target
    print(target.shape)
    trainX, testX, trainY, testY = train_test_split(data, target, train_size=TTS_training_size, random_state=TTS_random_state)
    #trainX, testX, trainY, testY = train_test_split(data, target, train_size, random_state=42)
    mean = trainY.mean()
    regressor.fit(trainX, trainY - mean)
    new_flat_picture = regressor.predict(data) + mean
    plt.imshow(new_flat_picture.reshape(height, width), cmap='gray')

    return new_flat_picture

# %%
def image_loader(Image_Path):
    paths = glob.glob(os.path.join(Image_Path, "*.jpeg"))
    paths.sort(key=lambda x:str(x[:-6])) # this part is depending on the type of file.
    image_list = []
    for i in range(len(paths)):
        temp_img = cv2.imread(paths[i])
        image_list.append(temp_img)
        
    return image_list

# %%
def tight_plot(img,count):
    plt.figure(figsize=(20, 20))   # change depends on the numbers of images
    gs1 = gridspec.GridSpec(5, round(count/5))
    gs1.update(wspace=0, hspace=0)
    for i in range(len(img)):
        ax = plt.subplot(gs1[i])
        ax.imshow(img[i])
        plt.axis('off')
        plt.subplots_adjust(wspace=0, hspace=0)
        #ax.set_title(str(i))
        ax.text(0.1,0.9,str(i),c="red",fontsize=16,ha='center', va='center', transform=ax.transAxes)
        ax.set_xticklabels([])
        ax.set_yticklabels([])
    #plt.savefig("total.jpg")    # save is you want to 
    plt.show()

# %%
def img_remove_white_edge(img_list):
    new_img_list = []
    for i in range(len(img_list)):
        temp_img = img_list[i]
        image = Image.fromarray(cv2.cvtColor(temp_img,cv2.COLOR_BGR2RGB))
        ivt_image = ImageOps.invert(image)
        bbox = ivt_image.getbbox()
        padding=(0, 0, 0, 0)
        left = bbox[0] - padding[0]
        top = bbox[1] - padding[1]
        right = bbox[2] + padding[2]
        bottom = bbox[3] + padding[3]
        cropped_image = image.crop([left, top, right, bottom]) 
        recover_img = cv2.cvtColor(np.array(cropped_image),cv2.COLOR_RGB2BGR)
        recover_img = cv2.resize(recover_img, (500,500))
        filter_img = cv2.bilateralFilter(src=recover_img, d=0, sigmaColor=100, sigmaSpace=10)
        new_img_list.append(filter_img)
    
    return new_img_list

# %%
def image_reconstruction(img_input_to_reconstruct, img_input, img_target, images_combined, count, trainsize, randomstate, regressor_nestimators, xgbmaxdepth, xgbsubsample, xgbnthreads, xgbeta):
    height, width = img_target.shape
    img_input_to_reconstruct = train_display(xgb.XGBRegressor(max_depth=xgbmaxdepth, n_estimators=regressor_nestimators, subsample=xgbsubsample, nthreads=xgbnthreads, eta=xgbeta), img_input_to_reconstruct, img_input, img_target, trainsize, randomstate)
    for i in np.arange(3,count-15):
        IMAG_input_train_image = images_combined[:,:,i,:]
        plt.imshow(IMAG_input_train_image.astype(np.uint8))
        plt.axis("off")
        plt.savefig('result_images/natural_results/training_images/input_train_image'+str(i)+'.jpeg')
        
        opened_input_train_image = Image.open('result_images/natural_results/training_images/input_train_image'+str(i)+'.jpeg')
        resize_input_train_image = opened_input_train_image.resize((500, 500))
        resize_input_train_image.save('result_images/natural_results/training_images/input_train_image'+str(i)+'_500x500.jpeg')
        img_train_input = np.asarray(Image.open('result_images/natural_results/training_images/input_train_image'+str(i)+'_500x500.jpeg')).mean(axis=2)

        img_input_to_reconstruct = train_display(xgb.XGBRegressor(max_depth=xgbmaxdepth, n_estimators=regressor_nestimators, subsample=xgbsubsample, nthreads=xgbnthreads, eta=xgbeta), img_input_to_reconstruct, img_train_input, img_target, trainsize, randomstate)

        plt.axis("off")
        plt.savefig('result_images/natural_results/reconstructed_images/reconstruction-'+str(10+(i-2)) +'.jpeg')
        print("Trained and Reconstructed Image - ", i-2)
    return img_input_to_reconstruct

# %%
def nii_to_image(nii,nimg,evts):
    stimtimes = evts[1:-1,0] # exclude first and last (times)
    stim_names = evts[1:-1,4] # exclude first and last (image names)
    trs = (stimtimes/2).astype(int) # because TR = 2 sec
    #print("Total Images created: ", trs.shape[0])
    avgstims = np.zeros([nii.shape[0],nii.shape[1],nii.shape[2],trs.shape[0]])
    images = np.zeros([500,500,trs.shape[0],3])
    #print("IMAGES Shape: ", images.shape)
    print("")
    count = 0
    for i in np.arange(0,trs.shape[0]):
        #convert 4d to 3d 
        avgstims[:,:,:,i] = np.mean(nimg[:,:,:,trs[i]+2:trs[i]+6],axis=3)
        #print(" Bold Image Chosen -", i, ": ", avgstims[:,:,:,i].shape)
        count = count + 1
        images[:,:,i,:] = imread('stimulus_images/stimulus_NaturalImageTrain/'+stim_names[i]+'.JPEG')
    return avgstims, images, count

# %%
#DATA PREPARATION        
nii = nib.load('bp_images/ses_natural_image_train/bp_NaturalImageTraining01_func_sub-01_run-01_bold.nii.gz')
nii_02 = nib.load('bp_images/ses_natural_image_train/bp_NaturalImageTraining01_func_sub-01_run-02_bold.nii.gz')
nii_03 = nib.load('bp_images/ses_natural_image_train/bp_NaturalImageTraining06_func_sub-01_run-01_bold.nii.gz')
nimg = nii.get_data()
nimg_02 = nii.get_data()
nimg_03 = nii.get_data()

evts = pd.read_csv('tsv_images/NaturalImageTrain/Events_NaturalImageTraining01_func_sub-01_run-01_events.tsv',sep='\t')
evts_02 = pd.read_csv('tsv_images/NaturalImageTrain/Events_NaturalImageTraining01_func_sub-01_run-02_events.tsv',sep='\t')
evts_03 = pd.read_csv('tsv_images/NaturalImageTrain/Events_NaturalImageTraining06_func_sub-01_run-01_events.tsv',sep='\t')
evts = np.asarray(evts)
evts_02 = np.asarray(evts_02)
evts_03 = np.asarray(evts_03)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   """
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   import sys

# %%
#THE LIST ALL OF IMAGES SEEN FOLLOWING WITH THE BRAIN IMAGES 
avgstims, images, count = nii_to_image(nii,nimg,evts)
print("Total Counter : ",count)
avgstims_02, images_02, count_02 = nii_to_image(nii_02,nimg_02,evts_02)
avgstims_03, images_03, count_03 = nii_to_image(nii_03,nimg_03,evts_03)
# Out:
# Total Counter :  55

# %%
images_combined = np.zeros([500,500,count*3,3])

# %%
count = 0
for i in np.arange(0,55):
    images_combined[:,:,i,:] = images[:,:,i,:]
    count = count + 1
    images_combined[:,:,i+55,:] = images_02[:,:,i,:]
    count = count + 1
    images_combined[:,:,i+110,:] = images_03[:,:,i,:]
    count = count + 1
    
print("Total Count = " , count)
# Out:
# Total Count =  165

# %%
#Testing Image Target
IMAG_frog = images_combined[:,:,0,:]
plt.imshow(IMAG_frog.astype(np.uint8)) #-> example picture for single slice 
print("Single Image Shape : ", IMAG_frog.shape)
print(IMAG_frog)
# Out:
# Single Image Shape :  (500, 500, 3)
# [[[182. 148. 136.]
#   [182. 148. 136.]
#   [182. 148. 136.]
#   ...
#   [134.  96.  95.]
#   [133.  95.  94.]
#   [132.  94.  93.]]
#
#  [[183. 149. 137.]
#   [183. 149. 137.]
#   [182. 148. 136.]
#   ...
#   [135.  97.  96.]
#   [134.  96.  95.]
#   [133.  95.  94.]]
#
#  [[185. 151. 139.]
#   [184. 150. 138.]
#   [183. 149. 137.]
#   ...
#   [135.  97.  96.]
#   [134.  96.  95.]
#   [133.  95.  94.]]
#
#  ...
#
#  [[ 56.  33.  43.]
#   [ 56.  33.  43.]
#   [ 54.  31.  41.]
#   ...
#   [ 89.  59.  67.]
#   [ 88.  58.  66.]
#   [ 87.  57.  65.]]
#
#  [[ 57.  34.  44.]
#   [ 56.  33.  43.]
#   [ 55.  32.  42.]
#   ...
#   [ 89.  59.  67.]
#   [ 88.  58.  66.]
#   [ 87.  57.  65.]]
#
#  [[ 57.  34.  44.]
#   [ 56.  33.  43.]
#   [ 55.  32.  42.]
#   ...
#   [ 89.  59.  67.]
#   [ 88.  58.  66.]
#   [ 87.  57.  65.]]]

# %%
# also show how to trim brain
for i in np.arange(0,count):
    plt.imshow(images_combined[:,:,i,:].astype(np.uint8))
    plt.axis("off")
    plt.savefig('result_images/natural_results/list_image_seen/image_seen-'+str(10+(i)) +'.jpeg')
    print(i+1," out of ",count," Seen Images Stored ") 
    #plt.imshow(avgstims[:,:,32,i].astype(np.uint8))
    #plt.imshow(avgstims[:,:,32,i])
# Out:
# 1  out of  165  Seen Images Stored
# 2  out of  165  Seen Images Stored
# 3  out of  165  Seen Images Stored
# 4  out of  165  Seen Images Stored
# 5  out of  165  Seen Images Stored
# 6  out of  165  Seen Images Stored
# 7  out of  165  Seen Images Stored
# 8  out of  165  Seen Images Stored
# 9  out of  165  Seen Images Stored
# 10  out of  165  Seen Images Stored
# 11  out of  165  Seen Images Stored
# 12  out of  165  Seen Images Stored
# 13  out of  165  Seen Images Stored
# 14  out of  165  Seen Images Stored
# 15  out of  165  Seen Images Stored
# 16  out of  165  Seen Images Stored
# 17  out of  165  Seen Images Stored
# 18  out of  165  Seen Images Stored
# 19  out of  165  Seen Images Stored
# 20  out of  165  Seen Images Stored
# 21  out of  165  Seen Images Stored
# 22  out of  165  Seen Images Stored
# 23  out of  165  Seen Images Stored
# 24  out of  165  Seen Images Stored
# 25  out of  165  Seen Images Stored
# 26  out of  165  Seen Images Stored
# 27  out of  165  Seen Images Stored
# 28  out of  165  Seen Images Stored
# 29  out of  165  Seen Images Stored
# 30  out of  165  Seen Images Stored
# 31  out of  165  Seen Images Stored
# 32  out of  165  Seen Images Stored
# 33  out of  165  Seen Images Stored
# 34  out of  165  Seen Images Stored
# 35  out of  165  Seen Images Stored
# 36  out of  165  Seen Images Stored
# 37  out of  165  Seen Images Stored
# 38  out of  165  Seen Images Stored
# 39  out of  165  Seen Images Stored
# 40  out of  165  Seen Images Stored
# 41  out of  165  Seen Images Stored
# 42  out of  165  Seen Images Stored
# 43  out of  165  Seen Images Stored
# 44  out of  165  Seen Images Stored
# 45  out of  165  Seen Images Stored
# 46  out of  165  Seen Images Stored
# 47  out of  165  Seen Images Stored
# 48  out of  165  Seen Images Stored
# 49  out of  165  Seen Images Stored
# 50  out of  165  Seen Images Stored
# 51  out of  165  Seen Images Stored
# 52  out of  165  Seen Images Stored
# 53  out of  165  Seen Images Stored
# 54  out of  165  Seen Images Stored
# 55  out of  165  Seen Images Stored
# 56  out of  165  Seen Images Stored
# 57  out of  165  Seen Images Stored
# 58  out of  165  Seen Images Stored
# 59  out of  165  Seen Images Stored
# 60  out of  165  Seen Images Stored
# 61  out of  165  Seen Images Stored
# 62  out of  165  Seen Images Stored
# 63  out of  165  Seen Images Stored
# 64  out of  165  Seen Images Stored
# 65  out of  165  Seen Images Stored
# 66  out of  165  Seen Images Stored
# 67  out of  165  Seen Images Stored
# 68  out of  165  Seen Images Stored
# 69  out of  165  Seen Images Stored
# 70  out of  165  Seen Images Stored
# 71  out of  165  Seen Images Stored
# 72  out of  165  Seen Images Stored
# 73  out of  165  Seen Images Stored
# 74  out of  165  Seen Images Stored
# 75  out of  165  Seen Images Stored
# 76  out of  165  Seen Images Stored
# 77  out of  165  Seen Images Stored
# 78  out of  165  Seen Images Stored
# 79  out of  165  Seen Images Stored
# 80  out of  165  Seen Images Stored
# 81  out of  165  Seen Images Stored
# 82  out of  165  Seen Images Stored
# 83  out of  165  Seen Images Stored
# 84  out of  165  Seen Images Stored
# 85  out of  165  Seen Images Stored
# 86  out of  165  Seen Images Stored
# 87  out of  165  Seen Images Stored
# 88  out of  165  Seen Images Stored
# 89  out of  165  Seen Images Stored
# 90  out of  165  Seen Images Stored
# 91  out of  165  Seen Images Stored
# 92  out of  165  Seen Images Stored
# 93  out of  165  Seen Images Stored
# 94  out of  165  Seen Images Stored
# 95  out of  165  Seen Images Stored
# 96  out of  165  Seen Images Stored
# 97  out of  165  Seen Images Stored
# 98  out of  165  Seen Images Stored
# 99  out of  165  Seen Images Stored
# 100  out of  165  Seen Images Stored
# 101  out of  165  Seen Images Stored
# 102  out of  165  Seen Images Stored
# 103  out of  165  Seen Images Stored
# 104  out of  165  Seen Images Stored
# 105  out of  165  Seen Images Stored
# 106  out of  165  Seen Images Stored
# 107  out of  165  Seen Images Stored
# 108  out of  165  Seen Images Stored
# 109  out of  165  Seen Images Stored
# 110  out of  165  Seen Images Stored
# 111  out of  165  Seen Images Stored
# 112  out of  165  Seen Images Stored
# 113  out of  165  Seen Images Stored
# 114  out of  165  Seen Images Stored
# 115  out of  165  Seen Images Stored
# 116  out of  165  Seen Images Stored
# 117  out of  165  Seen Images Stored
# 118  out of  165  Seen Images Stored
# 119  out of  165  Seen Images Stored
# 120  out of  165  Seen Images Stored
# 121  out of  165  Seen Images Stored
# 122  out of  165  Seen Images Stored
# 123  out of  165  Seen Images Stored
# 124  out of  165  Seen Images Stored
# 125  out of  165  Seen Images Stored
# 126  out of  165  Seen Images Stored
# 127  out of  165  Seen Images Stored
# 128  out of  165  Seen Images Stored
# 129  out of  165  Seen Images Stored
# 130  out of  165  Seen Images Stored
# 131  out of  165  Seen Images Stored
# 132  out of  165  Seen Images Stored
# 133  out of  165  Seen Images Stored
# 134  out of  165  Seen Images Stored
# 135  out of  165  Seen Images Stored
# 136  out of  165  Seen Images Stored
# 137  out of  165  Seen Images Stored
# 138  out of  165  Seen Images Stored
# 139  out of  165  Seen Images Stored
# 140  out of  165  Seen Images Stored
# 141  out of  165  Seen Images Stored
# 142  out of  165  Seen Images Stored
# 143  out of  165  Seen Images Stored
# 144  out of  165  Seen Images Stored
# 145  out of  165  Seen Images Stored
# 146  out of  165  Seen Images Stored
# 147  out of  165  Seen Images Stored
# 148  out of  165  Seen Images Stored
# 149  out of  165  Seen Images Stored
# 150  out of  165  Seen Images Stored
# 151  out of  165  Seen Images Stored
# 152  out of  165  Seen Images Stored
# 153  out of  165  Seen Images Stored
# 154  out of  165  Seen Images Stored
# 155  out of  165  Seen Images Stored
# 156  out of  165  Seen Images Stored
# 157  out of  165  Seen Images Stored
# 158  out of  165  Seen Images Stored
# 159  out of  165  Seen Images Stored
# 160  out of  165  Seen Images Stored
# 161  out of  165  Seen Images Stored
# 162  out of  165  Seen Images Stored
# 163  out of  165  Seen Images Stored
# 164  out of  165  Seen Images Stored
# 165  out of  165  Seen Images Stored

# %%
#FIRST TRIAL TRAINING
IMAG_input_image0 = images_combined[:,:,1,:]
plt.imshow(IMAG_input_image0.astype(np.uint8))
plt.axis("off")
plt.savefig('result_images/natural_results/training_images/input_training_image0.jpeg')
opened_input_image0 = Image.open('result_images/natural_results/training_images/input_training_image0.jpeg')
resize_input_image0 = opened_input_image0.resize((500, 500))
resize_input_image0.save('result_images/natural_results/training_images/input_training_image0_500x500.jpeg')
img_input_0 = np.asarray(Image.open('result_images/natural_results/training_images/input_training_image0_500x500.jpeg')).mean(axis=2)

IMAG_input_image = images_combined[:,:,2,:]
plt.imshow(IMAG_input_image.astype(np.uint8))
plt.axis("off")
plt.savefig('result_images/natural_results/training_images/input_training_image.jpeg')
opened_input_image = Image.open('result_images/natural_results/training_images/input_training_image.jpeg')
resize_input_image = opened_input_image.resize((500, 500))
resize_input_image.save('result_images/natural_results/training_images/input_training_image_500x500.jpeg')
img_input = np.asarray(Image.open('result_images/natural_results/training_images/input_training_image_500x500.jpeg')).mean(axis=2)

IMAG_target = images_combined[:,:,0,:]
plt.imshow(IMAG_target.astype(np.uint8))
plt.axis("off")
plt.savefig('result_images/natural_results/target_image/target_image.jpeg')
opened_img_target = Image.open('result_images/natural_results/target_image/target_image.jpeg')
resize_img_target = opened_img_target.resize((500, 500))
resize_img_target.save('result_images/natural_results/target_image/target_image_500x500.jpeg')
img_target = np.asarray(Image.open('result_images/natural_results/target_image/target_image_500x500.jpeg')).mean(axis=2)

# %%
#MAIN FUNCTION PROCESS OVERVIEW 
if __name__ == '__main__':
    target_picture = img_target
    image_to_reconstruct = img_input_0
    
    #PARAMETERS
    #Train Test Split Parameters
    Train_Test_Split_train_size = 0.60
    Train_Test_Split_random_state = 42
    #Regressor Parameters
    Regressor_n_estimators = 100
    #XG Boost Parameters
    XGB_maxdepth = 12
    XGB_subsample = 0.5
    XGB_nthreads = 4
    XGB_eta = 0.1

    #Apply Machine Learning, Training and Image Reconstruction
    #Method used for Machine Learning : Gradient Boosting (XG Boost)
    image_to_reconstruct = image_reconstruction(image_to_reconstruct, img_input, target_picture, images_combined, count, Train_Test_Split_train_size, Train_Test_Split_random_state, Regressor_n_estimators, XGB_maxdepth, XGB_subsample, XGB_nthreads, XGB_eta)    

    Show_Image_Reconstruction = "result_images/natural_results/reconstructed_images/"
    image_array_list = image_loader(Show_Image_Reconstruction)
    new_img = img_remove_white_edge(image_array_list)
    tight_plot(new_img,count)   
    plt.savefig('result_images/natural_results/result_reconstruction.jpeg')
# Out:
# (250000,)
# [13:25:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# (250000,)
# [13:25:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  1
# (250000,)
# [13:26:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  2
# (250000,)
# [13:26:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  3
# (250000,)
# [13:26:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  4
# (250000,)
# [13:26:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  5
# (250000,)
# [13:26:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  6
# (250000,)
# [13:27:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  7
# (250000,)
# [13:27:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  8
# (250000,)
# [13:27:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  9
# (250000,)
# [13:27:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  10
# (250000,)
# [13:28:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  11
# (250000,)
# [13:28:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  12
# (250000,)
# [13:28:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  13
# (250000,)
# [13:28:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  14
# (250000,)
# [13:28:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  15
# (250000,)
# [13:29:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  16
# (250000,)
# [13:29:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  17
# (250000,)
# [13:29:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  18
# (250000,)
# [13:29:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  19
# (250000,)
# [13:30:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  20
# (250000,)
# [13:30:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  21
# (250000,)
# [13:30:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  22
# (250000,)
# [13:30:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  23
# (250000,)
# [13:30:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  24
# (250000,)
# [13:31:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  25
# (250000,)
# [13:31:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  26
# (250000,)
# [13:31:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  27
# (250000,)
# [13:31:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  28
# (250000,)
# [13:32:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  29
# (250000,)
# [13:32:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  30
# (250000,)
# [13:32:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  31
# (250000,)
# [13:32:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  32
# (250000,)
# [13:32:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  33
# (250000,)
# [13:33:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  34
# (250000,)
# [13:33:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  35
# (250000,)
# [13:33:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  36
# (250000,)
# [13:33:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  37
# (250000,)
# [13:34:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  38
# (250000,)
# [13:34:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  39
# (250000,)
# [13:34:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  40
# (250000,)
# [13:34:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  41
# (250000,)
# [13:34:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  42
# (250000,)
# [13:35:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  43
# (250000,)
# [13:35:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  44
# (250000,)
# [13:35:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  45
# (250000,)
# [13:35:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  46
# (250000,)
# [13:36:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  47
# (250000,)
# [13:36:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  48
# (250000,)
# [13:36:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  49
# (250000,)
# [13:36:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  50
# (250000,)
# [13:37:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  51
# (250000,)
# [13:37:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  52
# (250000,)
# [13:37:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  53
# (250000,)
# [13:37:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  54
# (250000,)
# [13:38:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  55
# (250000,)
# [13:38:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  56
# (250000,)
# [13:38:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  57
# (250000,)
# [13:38:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  58
# (250000,)
# [13:39:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  59
# (250000,)
# [13:39:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  60
# (250000,)
# [13:39:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  61
# (250000,)
# [13:39:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  62
# (250000,)
# [13:40:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  63
# (250000,)
# [13:40:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  64
# (250000,)
# [13:40:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  65
# (250000,)
# [13:40:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  66
# (250000,)
# [13:41:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  67
# (250000,)
# [13:41:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  68
# (250000,)
# [13:41:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  69
# (250000,)
# [13:42:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  70
# (250000,)
# [13:42:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  71
# (250000,)
# [13:42:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  72
# (250000,)
# [13:42:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  73
# (250000,)
# [13:43:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  74
# (250000,)
# [13:43:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  75
# (250000,)
# [13:43:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  76
# (250000,)
# [13:43:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  77
# (250000,)
# [13:44:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  78
# (250000,)
# [13:44:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  79
# (250000,)
# [13:44:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  80
# (250000,)
# [13:45:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  81
# (250000,)
# [13:45:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  82
# (250000,)
# [13:45:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  83
# (250000,)
# [13:46:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  84
# (250000,)
# [13:46:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  85
# (250000,)
# [13:46:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  86
# (250000,)
# [13:46:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  87
# (250000,)
# [13:47:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  88
# (250000,)
# [13:47:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  89
# (250000,)
# [13:47:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  90
# (250000,)
# [13:48:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  91
# (250000,)
# [13:48:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  92
# (250000,)
# [13:48:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  93
# (250000,)
# [13:49:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  94
# (250000,)
# [13:49:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  95
# (250000,)
# [13:49:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  96
# (250000,)
# [13:49:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  97
# (250000,)
# [13:50:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  98
# (250000,)
# [13:50:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  99
# (250000,)
# [13:50:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  100
# (250000,)
# [13:51:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  101
# (250000,)
# [13:51:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  102
# (250000,)
# [13:51:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  103
# (250000,)
# [13:52:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  104
# (250000,)
# [13:52:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  105
# (250000,)
# [13:52:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  106
# (250000,)
# [13:53:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  107
# (250000,)
# [13:53:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  108
# (250000,)
# [13:53:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  109
# (250000,)
# [13:54:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  110
# (250000,)
# [13:54:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  111
# (250000,)
# [13:55:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  112
# (250000,)
# [13:55:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  113
# (250000,)
# [13:55:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  114
# (250000,)
# [13:56:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  115
# (250000,)
# [13:56:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  116
# (250000,)
# [13:56:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  117
# (250000,)
# [13:57:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  118
# (250000,)
# [13:57:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  119
# (250000,)
# [13:57:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  120
# (250000,)
# [13:58:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  121
# (250000,)
# [13:58:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  122
# (250000,)
# [13:58:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  123
# (250000,)
# [13:59:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  124
# (250000,)
# [13:59:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  125
# (250000,)
# [14:00:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  126
# (250000,)
# [14:00:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  127
# (250000,)
# [14:00:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  128
# (250000,)
# [14:01:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  129
# (250000,)
# [14:01:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  130
# (250000,)
# [14:02:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  131
# (250000,)
# [14:02:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  132
# (250000,)
# [14:02:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  133
# (250000,)
# [14:03:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  134
# (250000,)
# [14:03:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  135
# (250000,)
# [14:03:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  136
# (250000,)
# [14:04:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  137
# (250000,)
# [14:04:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  138
# (250000,)
# [14:05:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  139
# (250000,)
# [14:05:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  140
# (250000,)
# [14:05:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  141
# (250000,)
# [14:06:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  142
# (250000,)
# [14:06:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  143
# (250000,)
# [14:07:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  144
# (250000,)
# [14:07:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  145
# (250000,)
# [14:08:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  146
# (250000,)
# [14:08:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Trained and Reconstructed Image -  147

# %%
#LIST OF MACHINE LEARNING CHOICES#
    
#train_display(LinearRegression(), image)
#train_display(DecisionTreeRegressor(max_depth=10), image)
#train_display(DecisionTreeRegressor(max_depth=20), image)
#train_display(DecisionTreeRegressor(min_samples_leaf=40), image)
#train_display(DecisionTreeRegressor(min_samples_leaf=5), image)
#train_display(RandomForestRegressor(n_estimators=100), image)
#train_display(KNeighborsRegressor(n_neighbors=2), image)
#train_display(KNeighborsRegressor(n_neighbors=5, weights='distance'), image)
#train_display(KNeighborsRegressor(n_neighbors=25, weights='distance'), image)
#train_display(KNeighborsRegressor(n_neighbors=2, metric='canberra'), image)
#train_display(XGBoostRegressor(max_depth=5, n_estimators=100, subsample=0.5, nthreads=4), img_input1, img_input2, img_target)
#train_display(XGBoostRegressor(max_depth=12, n_estimators=100, subsample=0.5, nthreads=4, eta=0.1), img_input1, img_input2, img_target)

#train_display(TheanetsRegressor(layers=[20, 20], hidden_activation='tanh', 
#                                trainers=[{'algo': 'adadelta', 'learning_rate': 0.01}]), img_input1, img_input2, img_target)

#train_display(TheanetsRegressor(layers=[40, 40, 40, 40], hidden_activation='tanh', 
#                                trainers=[{'algo': 'adadelta', 'learning_rate': 0.01}]), img_input1, img_input2, img_target)


#base = make_pipeline(GaussianRandomProjection(n_components=10), 
#                     DecisionTreeRegressor(max_depth=10, max_features=5))
#train_display(AdaBoostRegressor(base, n_estimators=50, learning_rate=0.05), img_input1, img_input2, img_target)

#
#base = make_pipeline(GaussianRandomProjection(n_components=15), 
#                     DecisionTreeRegressor(max_depth=12, max_features=5))
#train_display(BaggingRegressor(base, n_estimators=100), img_input1, img_input2, img_target)
